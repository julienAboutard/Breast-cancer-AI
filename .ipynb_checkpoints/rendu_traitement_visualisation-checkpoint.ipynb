# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from IPython.display import display_html

# %%
# Lecture du fichier .csv
breast_cancer_df = pd.read_csv("breast_cancer.csv")

# %%
# Affichage de quelques lignes du dataframe pour montrer sa structure.
breast_cancer_df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # Présentation des différentes variables de la base et de leur type.
#
# "id" : identifiant de l'échantillon prélevé
# "diagnosis" : diagnostique établi : M = malin, B = bénin
# "xxx_mean" : valeur moyenne mesurée
# "xxx_se" : écart-type de la marge d'erreur de mesure
# "xxx_worst" : valeur mesurée la plus élevée
# "radius" : rayon moyen de la cellule prélevée
# "texture" : écart-type sur le niveau de gris des pixels composant l'image de la cellule. Le niveau de gris minimum est 0, le niveau maximum est de 255 (pour une image de 8 bits).
# "perimeter" : périmètre de la cellule prélevée
# "area" : aire de la cellule prélevée
# "smoothness" : variation dans la mesure du rayon de la cellule
# "compactness" : (périmètre^2 / aire - 1.0)
# "concavity" : degré d'irrégularité du contour de la cellule
# "concave points" : nombre de portions irrégulières sur le contour de la cellule
# "symmetry" : niveau de symétrie de la cellule prélevée
# "fractal dimension" : niveau d'irrégularité du contour de la cellule prélevée par rapport à ses cellules environnantes

# %% [markdown]
# # Statistiques descriptives sur chacune des variables en fonction de leur type.

# %%
breast_cancer_df.loc[:, ["radius_mean", "radius_se", "radius_worst"]].describe()
# Out:
#        radius_mean   radius_se  radius_worst
# count   569.000000  569.000000    569.000000
# mean     14.127292    0.405172     16.269190
# std       3.524049    0.277313      4.833242
# min       6.981000    0.111500      7.930000
# 25%      11.700000    0.232400     13.010000
# 50%      13.370000    0.324200     14.970000
# 75%      15.780000    0.478900     18.790000
# max      28.110000    2.873000     36.040000

# %%
breast_cancer_df.loc[:, ["texture_mean", "texture_se", "texture_worst"]].describe()
# Out:
#        texture_mean  texture_se  texture_worst
# count    569.000000  569.000000     569.000000
# mean      19.289649    1.216853      25.677223
# std        4.301036    0.551648       6.146258
# min        9.710000    0.360200      12.020000
# 25%       16.170000    0.833900      21.080000
# 50%       18.840000    1.108000      25.410000
# 75%       21.800000    1.474000      29.720000
# max       39.280000    4.885000      49.540000

# %%
breast_cancer_df.loc[:, ["perimeter_mean", "perimeter_se", "perimeter_worst"]].describe()
# Out:
#        perimeter_mean  perimeter_se  perimeter_worst
# count      569.000000    569.000000       569.000000
# mean        91.969033      2.866059       107.261213
# std         24.298981      2.021855        33.602542
# min         43.790000      0.757000        50.410000
# 25%         75.170000      1.606000        84.110000
# 50%         86.240000      2.287000        97.660000
# 75%        104.100000      3.357000       125.400000
# max        188.500000     21.980000       251.200000

# %%
breast_cancer_df.loc[:, ["area_mean", "area_se", "area_worst"]].describe()
# Out:
#          area_mean     area_se   area_worst
# count   569.000000  569.000000   569.000000
# mean    654.889104   40.337079   880.583128
# std     351.914129   45.491006   569.356993
# min     143.500000    6.802000   185.200000
# 25%     420.300000   17.850000   515.300000
# 50%     551.100000   24.530000   686.500000
# 75%     782.700000   45.190000  1084.000000
# max    2501.000000  542.200000  4254.000000

# %%
breast_cancer_df.loc[:, ["smoothness_mean", "smoothness_se", "smoothness_worst"]].describe()
# Out:
#        smoothness_mean  smoothness_se  smoothness_worst
# count       569.000000     569.000000        569.000000
# mean          0.096360       0.007041          0.132369
# std           0.014064       0.003003          0.022832
# min           0.052630       0.001713          0.071170
# 25%           0.086370       0.005169          0.116600
# 50%           0.095870       0.006380          0.131300
# 75%           0.105300       0.008146          0.146000
# max           0.163400       0.031130          0.222600

# %%
breast_cancer_df.loc[:, ["compactness_mean", "compactness_se", "compactness_worst"]].describe()
# Out:
#        compactness_mean  compactness_se  compactness_worst
# count        569.000000      569.000000         569.000000
# mean           0.104341        0.025478           0.254265
# std            0.052813        0.017908           0.157336
# min            0.019380        0.002252           0.027290
# 25%            0.064920        0.013080           0.147200
# 50%            0.092630        0.020450           0.211900
# 75%            0.130400        0.032450           0.339100
# max            0.345400        0.135400           1.058000

# %%
breast_cancer_df.loc[:, ["concavity_mean", "concavity_se", "concavity_worst"]].describe()
# Out:
#        concavity_mean  concavity_se  concavity_worst
# count      569.000000    569.000000       569.000000
# mean         0.088799      0.031894         0.272188
# std          0.079720      0.030186         0.208624
# min          0.000000      0.000000         0.000000
# 25%          0.029560      0.015090         0.114500
# 50%          0.061540      0.025890         0.226700
# 75%          0.130700      0.042050         0.382900
# max          0.426800      0.396000         1.252000

# %%
breast_cancer_df.loc[:, ["concave points_mean", "concave points_se", "concave points_worst"]].describe()
# Out:
#        concave points_mean  concave points_se  concave points_worst
# count           569.000000         569.000000            569.000000
# mean              0.048919           0.011796              0.114606
# std               0.038803           0.006170              0.065732
# min               0.000000           0.000000              0.000000
# 25%               0.020310           0.007638              0.064930
# 50%               0.033500           0.010930              0.099930
# 75%               0.074000           0.014710              0.161400
# max               0.201200           0.052790              0.291000

# %%
breast_cancer_df.loc[:, ["symmetry_mean", "symmetry_se", "symmetry_worst"]].describe()
# Out:
#        symmetry_mean  symmetry_se  symmetry_worst
# count     569.000000   569.000000      569.000000
# mean        0.181162     0.020542        0.290076
# std         0.027414     0.008266        0.061867
# min         0.106000     0.007882        0.156500
# 25%         0.161900     0.015160        0.250400
# 50%         0.179200     0.018730        0.282200
# 75%         0.195700     0.023480        0.317900
# max         0.304000     0.078950        0.663800

# %%
breast_cancer_df.loc[:, ["fractal_dimension_mean", "fractal_dimension_se", "fractal_dimension_worst"]].describe()
# Out:
#        fractal_dimension_mean  fractal_dimension_se  fractal_dimension_worst
# count              569.000000            569.000000               569.000000
# mean                 0.062798              0.003795                 0.083946
# std                  0.007060              0.002646                 0.018061
# min                  0.049960              0.000895                 0.055040
# 25%                  0.057700              0.002248                 0.071460
# 50%                  0.061540              0.003187                 0.080040
# 75%                  0.066120              0.004558                 0.092080
# max                  0.097440              0.029840                 0.207500

# %% [markdown]
# # Présenter des statistiques par diagnostic (bénin/malin) pour les variables, permettant de mettre en évidence l'aspect plus ou moins discriminant de certaines variables.

# %%
radius_df=breast_cancer_df.loc[:, ["diagnosis", "radius_mean", "radius_se", "radius_worst"]]
radius_df.style.set_caption("radius for B diagnosis")

radius_B_df = radius_df[radius_df['diagnosis']=='B']
radius_M_df = radius_df[radius_df['diagnosis']=='M']

df1_styler = radius_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('radius for B diagnosis')
df2_styler = radius_M_df.describe().style.set_table_attributes("style='display:inline'").set_caption('radius for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_cf920" style='display:inline'>
#   <caption>radius for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf920_level0_col0" class="col_heading level0 col0" >radius_mean</th>
#       <th id="T_cf920_level0_col1" class="col_heading level0 col1" >radius_se</th>
#       <th id="T_cf920_level0_col2" class="col_heading level0 col2" >radius_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf920_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_cf920_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_cf920_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_cf920_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cf920_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_cf920_row1_col0" class="data row1 col0" >12.146524</td>
# ...

# %%
texture_df=breast_cancer_df.loc[:, ["diagnosis", "texture_mean", "texture_se", "texture_worst"]]
texture_df.style.set_caption("texture for B diagnosis")

texture_B_df = texture_df[texture_df['diagnosis']=='B']
texture_M_df = texture_df[texture_df['diagnosis']=='M']

df1_styler = texture_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('texture for B diagnosis')
df2_styler = texture_M_df.describe().style.set_table_attributes("style='display:inline'").set_caption('texture for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ae4e7" style='display:inline'>
#   <caption>texture for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae4e7_level0_col0" class="col_heading level0 col0" >texture_mean</th>
#       <th id="T_ae4e7_level0_col1" class="col_heading level0 col1" >texture_se</th>
#       <th id="T_ae4e7_level0_col2" class="col_heading level0 col2" >texture_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae4e7_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_ae4e7_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_ae4e7_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_ae4e7_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae4e7_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_ae4e7_row1_col0" class="data row1 col0" >17.914762</td>
# ...

# %%
perimeter_df=breast_cancer_df.loc[:, ["diagnosis", "perimeter_mean", "perimeter_se", "perimeter_worst"]]
perimeter_df.style.set_caption("perimeter for B diagnosis")

perimeter_B_df = perimeter_df[perimeter_df['diagnosis']=='B']
perimeter_M_df = perimeter_df[perimeter_df['diagnosis']=='M']

df1_styler = perimeter_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('perimeter for B diagnosis')
df2_styler = perimeter_M_df.describe().style.set_table_attributes("style='display:inline'").set_caption('perimeter for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2c190" style='display:inline'>
#   <caption>perimeter for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c190_level0_col0" class="col_heading level0 col0" >perimeter_mean</th>
#       <th id="T_2c190_level0_col1" class="col_heading level0 col1" >perimeter_se</th>
#       <th id="T_2c190_level0_col2" class="col_heading level0 col2" >perimeter_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c190_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_2c190_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_2c190_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_2c190_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2c190_level0_row1" class="row_heading level0 row1" >mean</th>
# ...

# %%
area_df=breast_cancer_df.loc[:, ["diagnosis", "area_mean", "area_se", "area_worst"]]
area_df.style.set_caption("area for B diagnosis")

area_B_df = area_df[area_df['diagnosis']=='B']
area_M_df = area_df[area_df['diagnosis']=='M']

df1_styler = area_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('area for B diagnosis')
df2_styler = area_M_df.describe().style.set_table_attributes("style='display:inline'").set_caption('area for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_18fdf" style='display:inline'>
#   <caption>area for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18fdf_level0_col0" class="col_heading level0 col0" >area_mean</th>
#       <th id="T_18fdf_level0_col1" class="col_heading level0 col1" >area_se</th>
#       <th id="T_18fdf_level0_col2" class="col_heading level0 col2" >area_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18fdf_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_18fdf_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_18fdf_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_18fdf_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18fdf_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_18fdf_row1_col0" class="data row1 col0" >462.790196</td>
# ...

# %%
smoothness_df=breast_cancer_df.loc[:, ["diagnosis", "smoothness_mean", "smoothness_se", "smoothness_worst"]]
smoothness_df.style.set_caption("smoothness for B diagnosis")

smoothness_B_df = smoothness_df[smoothness_df['diagnosis']=='B']
smoothness_M_df = smoothness_df[smoothness_df['diagnosis']=='M']

df1_styler = smoothness_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('smoothness for B diagnosis')
df2_styler = smoothness_M_df.describe().style.set_table_attributes("style='display:inline'").set_caption('smoothness for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bc098" style='display:inline'>
#   <caption>smoothness for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc098_level0_col0" class="col_heading level0 col0" >smoothness_mean</th>
#       <th id="T_bc098_level0_col1" class="col_heading level0 col1" >smoothness_se</th>
#       <th id="T_bc098_level0_col2" class="col_heading level0 col2" >smoothness_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc098_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_bc098_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_bc098_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_bc098_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bc098_level0_row1" class="row_heading level0 row1" >mean</th>
# ...

# %%
compactness_df=breast_cancer_df.loc[:, ["diagnosis", "compactness_mean", "compactness_se", "compactness_worst"]]
compactness_df.style.set_caption("compactness for B diagnosis")

compactness_B_df = compactness_df[compactness_df['diagnosis']=='B'].describe()
compactness_M_df = compactness_df[compactness_df['diagnosis']=='M'].describe()

df1_styler = compactness_B_df.style.set_table_attributes("style='display:inline'").set_caption('compactness for B diagnosis')
df2_styler = compactness_M_df.style.set_table_attributes("style='display:inline'").set_caption('compactness for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8f94c" style='display:inline'>
#   <caption>compactness for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f94c_level0_col0" class="col_heading level0 col0" >compactness_mean</th>
#       <th id="T_8f94c_level0_col1" class="col_heading level0 col1" >compactness_se</th>
#       <th id="T_8f94c_level0_col2" class="col_heading level0 col2" >compactness_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f94c_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_8f94c_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_8f94c_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_8f94c_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8f94c_level0_row1" class="row_heading level0 row1" >mean</th>
# ...

# %%
concavity_df=breast_cancer_df.loc[:, ["diagnosis", "concavity_mean", "concavity_se", "concavity_worst"]]
concavity_df.style.set_caption("concavity for B diagnosis")

concavity_B_df = concavity_df[concavity_df['diagnosis']=='B'].describe()
concavity_M_df = concavity_df[concavity_df['diagnosis']=='M'].describe()

df1_styler = concavity_B_df.style.set_table_attributes("style='display:inline'").set_caption('concavity for B diagnosis')
df2_styler = concavity_M_df.style.set_table_attributes("style='display:inline'").set_caption('concavity for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8bd7f" style='display:inline'>
#   <caption>concavity for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bd7f_level0_col0" class="col_heading level0 col0" >concavity_mean</th>
#       <th id="T_8bd7f_level0_col1" class="col_heading level0 col1" >concavity_se</th>
#       <th id="T_8bd7f_level0_col2" class="col_heading level0 col2" >concavity_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bd7f_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_8bd7f_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_8bd7f_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_8bd7f_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd7f_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_8bd7f_row1_col0" class="data row1 col0" >0.046058</td>
# ...

# %%
concave_points_df=breast_cancer_df.loc[:, ["diagnosis", "concave points_mean", "concave points_se", "concave points_worst"]]
concave_points_df.style.set_caption("concave points for B diagnosis")

concave_points_B_df = concave_points_df[concave_points_df['diagnosis']=='B'].describe()
concave_points_M_df = concave_points_df[concave_points_df['diagnosis']=='M'].describe()

df1_styler = concave_points_B_df.style.set_table_attributes("style='display:inline'").set_caption('concave points for B diagnosis')
df2_styler = concave_points_M_df.style.set_table_attributes("style='display:inline'").set_caption('concave points for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c627b" style='display:inline'>
#   <caption>concave points for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c627b_level0_col0" class="col_heading level0 col0" >concave points_mean</th>
#       <th id="T_c627b_level0_col1" class="col_heading level0 col1" >concave points_se</th>
#       <th id="T_c627b_level0_col2" class="col_heading level0 col2" >concave points_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c627b_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_c627b_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_c627b_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_c627b_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c627b_level0_row1" class="row_heading level0 row1" >mean</th>
# ...

# %%
symmetry_df=breast_cancer_df.loc[:, ["diagnosis", "symmetry_mean", "symmetry_se", "symmetry_worst"]]
symmetry_df.style.set_caption("symmetry for B diagnosis")

symmetry_B_df = symmetry_df[symmetry_df['diagnosis']=='B'].describe()
symmetry_M_df = symmetry_df[symmetry_df['diagnosis']=='M'].describe()

df1_styler = symmetry_B_df.style.set_table_attributes("style='display:inline'").set_caption('symmetry for B diagnosis')
df2_styler = symmetry_M_df.style.set_table_attributes("style='display:inline'").set_caption('symmetry for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_80697" style='display:inline'>
#   <caption>symmetry for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80697_level0_col0" class="col_heading level0 col0" >symmetry_mean</th>
#       <th id="T_80697_level0_col1" class="col_heading level0 col1" >symmetry_se</th>
#       <th id="T_80697_level0_col2" class="col_heading level0 col2" >symmetry_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80697_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_80697_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_80697_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_80697_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_80697_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_80697_row1_col0" class="data row1 col0" >0.174186</td>
# ...

# %%
fractal_dimension_df=breast_cancer_df.loc[:, ["diagnosis", "fractal_dimension_mean", "fractal_dimension_se", "fractal_dimension_worst"]]
fractal_dimension_df.style.set_caption("fractal_dimension for B diagnosis")

fractal_dimension_B_df = fractal_dimension_df[fractal_dimension_df['diagnosis']=='B'].describe()
fractal_dimension_M_df = fractal_dimension_df[fractal_dimension_df['diagnosis']=='M'].describe()

df1_styler = fractal_dimension_B_df.style.set_table_attributes("style='display:inline'").set_caption('fractal_dimension for B diagnosis')
df2_styler = fractal_dimension_M_df.style.set_table_attributes("style='display:inline'").set_caption('fractal_dimension for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_101c4" style='display:inline'>
#   <caption>fractal_dimension for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_101c4_level0_col0" class="col_heading level0 col0" >fractal_dimension_mean</th>
#       <th id="T_101c4_level0_col1" class="col_heading level0 col1" >fractal_dimension_se</th>
#       <th id="T_101c4_level0_col2" class="col_heading level0 col2" >fractal_dimension_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_101c4_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_101c4_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_101c4_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_101c4_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_101c4_level0_row1" class="row_heading level0 row1" >mean</th>
# ...

# %%
print(f'ratio rayon M par rapport à rayon B : {int(radius_M_df["radius_mean"].mean()/radius_B_df["radius_mean"].mean()*100)} %')
print(f'ratio texture M par rapport à texture B : {int(texture_M_df["texture_mean"].mean()/texture_B_df["texture_mean"].mean()*100)} %')
print(f'ratio périmètre M par rapport à périmètre B : {int(perimeter_M_df["perimeter_mean"].mean()/perimeter_B_df["perimeter_mean"].mean()*100)} %')
print(f'ratio aire M par rapport à aire B : {int(area_M_df["area_mean"].mean()/area_B_df["area_mean"].mean()*100)} %')
print(f'ratio "smoothness" M par rapport à smoothness B : {int(smoothness_M_df["smoothness_mean"].mean()/smoothness_B_df["smoothness_mean"].mean()*100)} %')
# Out:
# ratio rayon M par rapport à rayon B : 143 %
# ratio texture M par rapport à texture B : 120 %
# ratio périmètre M par rapport à périmètre B : 147 %
# ratio aire M par rapport à aire B : 211 %
# ratio "smoothness" M par rapport à smoothness B : 111 %

# %%
print(f'ratio rayon M par rapport à rayon B : {int(radius_M_df["radius_worst"].mean()/radius_B_df["radius_worst"].mean()*100)} %')
print(f'ratio texture M par rapport à texture B : {int(texture_M_df["texture_worst"].mean()/texture_B_df["texture_worst"].mean()*100)} %')
print(f'ratio périmètre M par rapport à périmètre B : {int(perimeter_M_df["perimeter_worst"].mean()/perimeter_B_df["perimeter_worst"].mean()*100)} %')
print(f'ratio aire M par rapport à aire B : {int(area_M_df["area_worst"].mean()/area_B_df["area_worst"].mean()*100)} %')
print(f'ratio smoothness M par rapport à smoothness B : {int(smoothness_M_df["smoothness_worst"].mean()/smoothness_B_df["smoothness_worst"].mean()*100)} %')
# Out:
# ratio rayon M par rapport à rayon B : 157 %
# ratio texture M par rapport à texture B : 124 %
# ratio périmètre M par rapport à périmètre B : 162 %
# ratio aire M par rapport à aire B : 254 %
# ratio smoothness M par rapport à smoothness B : 115 %

# %%
print(f'ratio rayon M par rapport à rayon B : {int(radius_df["radius_se"].mean()/radius_df["radius_mean"].mean()*100)} %')
print(f'ratio texture M par rapport à texture B : {int(texture_df["texture_se"].mean()/texture_df["texture_mean"].mean()*100)} %')
print(f'ratio périmètre M par rapport à périmètre B : {int(perimeter_df["perimeter_se"].mean()/perimeter_df["perimeter_mean"].mean()*100)} %')
print(f'ratio aire M par rapport à aire B : {int(area_df["area_se"].mean()/area_df["area_mean"].mean()*100)} %')
print(f'ratio smoothness M par rapport à smoothness B : {int(smoothness_df["smoothness_se"].mean()/smoothness_df["smoothness_mean"].mean()*100)} %')
# Out:
# ratio rayon M par rapport à rayon B : 2 %
# ratio texture M par rapport à texture B : 6 %
# ratio périmètre M par rapport à périmètre B : 3 %
# ratio aire M par rapport à aire B : 6 %
# ratio smoothness M par rapport à smoothness B : 7 %
