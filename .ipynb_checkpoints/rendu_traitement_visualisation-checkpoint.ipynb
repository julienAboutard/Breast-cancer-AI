# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from IPython.display import display_html

# %%
# Lecture du fichier .csv
breast_cancer_df = pd.read_csv("breast_cancer.csv")

# %%
# Affichage de quelques lignes du dataframe pour montrer sa structure.
breast_cancer_df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# # Présentation des différentes variables de la base et de leur type.
#
# "id" : identifiant de l'échantillon prélevé
# "diagnosis" : diagnostique établi : M = malin, B = bénin
# "xxx_mean" : valeur moyenne mesurée
# "xxx_se" : écart-type de la marge d'erreur de mesure
# "xxx_worst" : valeur mesurée la plus élevée
# "radius" : rayon moyen de la cellule prélevée
# "texture" : écart-type sur le niveau de gris des pixels composant l'image de la cellule. Le niveau de gris minimum est 0, le niveau maximum est de 255 (pour une image de 8 bits).
# "perimeter" : périmètre de la cellule prélevée
# "area" : aire de la cellule prélevée
# "smoothness" : variation dans la mesure du rayon de la cellule
# "compactness" : (périmètre^2 / aire - 1.0)
# "concavity" : degré d'irrégularité du contour de la cellule
# "concave points" : nombre de portions irrégulières sur le contour de la cellule
# "symmetry" : niveau de symétrie de la cellule prélevée
# "fractal dimension" : niveau d'irrégularité du contour de la cellule prélevée par rapport à ses cellules environnantes

# %% [markdown]
# # Statistiques descriptives sur chacune des variables en fonction de leur type.

# %%
breast_cancer_df.loc[:, ["radius_mean", "radius_se", "radius_worst"]].describe()
# Out:
#        radius_mean   radius_se  radius_worst
# count   569.000000  569.000000    569.000000
# mean     14.127292    0.405172     16.269190
# std       3.524049    0.277313      4.833242
# min       6.981000    0.111500      7.930000
# 25%      11.700000    0.232400     13.010000
# 50%      13.370000    0.324200     14.970000
# 75%      15.780000    0.478900     18.790000
# max      28.110000    2.873000     36.040000

# %%
breast_cancer_df.loc[:, ["texture_mean", "texture_se", "texture_worst"]].describe()
# Out:
#        texture_mean  texture_se  texture_worst
# count    569.000000  569.000000     569.000000
# mean      19.289649    1.216853      25.677223
# std        4.301036    0.551648       6.146258
# min        9.710000    0.360200      12.020000
# 25%       16.170000    0.833900      21.080000
# 50%       18.840000    1.108000      25.410000
# 75%       21.800000    1.474000      29.720000
# max       39.280000    4.885000      49.540000

# %%
breast_cancer_df.loc[:, ["perimeter_mean", "perimeter_se", "perimeter_worst"]].describe()
# Out:
#        perimeter_mean  perimeter_se  perimeter_worst
# count      569.000000    569.000000       569.000000
# mean        91.969033      2.866059       107.261213
# std         24.298981      2.021855        33.602542
# min         43.790000      0.757000        50.410000
# 25%         75.170000      1.606000        84.110000
# 50%         86.240000      2.287000        97.660000
# 75%        104.100000      3.357000       125.400000
# max        188.500000     21.980000       251.200000

# %%
breast_cancer_df.loc[:, ["area_mean", "area_se", "area_worst"]].describe()
# Out:
#          area_mean     area_se   area_worst
# count   569.000000  569.000000   569.000000
# mean    654.889104   40.337079   880.583128
# std     351.914129   45.491006   569.356993
# min     143.500000    6.802000   185.200000
# 25%     420.300000   17.850000   515.300000
# 50%     551.100000   24.530000   686.500000
# 75%     782.700000   45.190000  1084.000000
# max    2501.000000  542.200000  4254.000000

# %%
breast_cancer_df.loc[:, ["smoothness_mean", "smoothness_se", "smoothness_worst"]].describe()
# Out:
#        smoothness_mean  smoothness_se  smoothness_worst
# count       569.000000     569.000000        569.000000
# mean          0.096360       0.007041          0.132369
# std           0.014064       0.003003          0.022832
# min           0.052630       0.001713          0.071170
# 25%           0.086370       0.005169          0.116600
# 50%           0.095870       0.006380          0.131300
# 75%           0.105300       0.008146          0.146000
# max           0.163400       0.031130          0.222600

# %%
breast_cancer_df.loc[:, ["compactness_mean", "compactness_se", "compactness_worst"]].describe()
# Out:
#        compactness_mean  compactness_se  compactness_worst
# count        569.000000      569.000000         569.000000
# mean           0.104341        0.025478           0.254265
# std            0.052813        0.017908           0.157336
# min            0.019380        0.002252           0.027290
# 25%            0.064920        0.013080           0.147200
# 50%            0.092630        0.020450           0.211900
# 75%            0.130400        0.032450           0.339100
# max            0.345400        0.135400           1.058000

# %%
breast_cancer_df.loc[:, ["concavity_mean", "concavity_se", "concavity_worst"]].describe()
# Out:
#        concavity_mean  concavity_se  concavity_worst
# count      569.000000    569.000000       569.000000
# mean         0.088799      0.031894         0.272188
# std          0.079720      0.030186         0.208624
# min          0.000000      0.000000         0.000000
# 25%          0.029560      0.015090         0.114500
# 50%          0.061540      0.025890         0.226700
# 75%          0.130700      0.042050         0.382900
# max          0.426800      0.396000         1.252000

# %%
breast_cancer_df.loc[:, ["concave points_mean", "concave points_se", "concave points_worst"]].describe()
# Out:
#        concave points_mean  concave points_se  concave points_worst
# count           569.000000         569.000000            569.000000
# mean              0.048919           0.011796              0.114606
# std               0.038803           0.006170              0.065732
# min               0.000000           0.000000              0.000000
# 25%               0.020310           0.007638              0.064930
# 50%               0.033500           0.010930              0.099930
# 75%               0.074000           0.014710              0.161400
# max               0.201200           0.052790              0.291000

# %%
breast_cancer_df.loc[:, ["symmetry_mean", "symmetry_se", "symmetry_worst"]].describe()
# Out:
#        symmetry_mean  symmetry_se  symmetry_worst
# count     569.000000   569.000000      569.000000
# mean        0.181162     0.020542        0.290076
# std         0.027414     0.008266        0.061867
# min         0.106000     0.007882        0.156500
# 25%         0.161900     0.015160        0.250400
# 50%         0.179200     0.018730        0.282200
# 75%         0.195700     0.023480        0.317900
# max         0.304000     0.078950        0.663800

# %%
breast_cancer_df.loc[:, ["fractal_dimension_mean", "fractal_dimension_se", "fractal_dimension_worst"]].describe()
# Out:
#        fractal_dimension_mean  fractal_dimension_se  fractal_dimension_worst
# count              569.000000            569.000000               569.000000
# mean                 0.062798              0.003795                 0.083946
# std                  0.007060              0.002646                 0.018061
# min                  0.049960              0.000895                 0.055040
# 25%                  0.057700              0.002248                 0.071460
# 50%                  0.061540              0.003187                 0.080040
# 75%                  0.066120              0.004558                 0.092080
# max                  0.097440              0.029840                 0.207500

# %% [markdown]
# # Présenter des statistiques par diagnostic (bénin/malin) pour les variables, permettant de mettre en évidence l'aspect plus ou moins discriminant de certaines variables.

# %%
radius_df=breast_cancer_df.loc[:, ["diagnosis", "radius_mean", "radius_se", "radius_worst"]]
radius_df.style.set_caption("radius for B diagnosis")

radius_B_df = radius_df[radius_df['diagnosis']=='B']
radius_M_df = radius_df[radius_df['diagnosis']=='M']

df1_styler = radius_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('radius for B diagnosis')
df2_styler = radius_M_df.describe().style.set_table_attributes("style='display:inline'").set_caption('radius for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_430cf" style='display:inline'>
#   <caption>radius for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_430cf_level0_col0" class="col_heading level0 col0" >radius_mean</th>
#       <th id="T_430cf_level0_col1" class="col_heading level0 col1" >radius_se</th>
#       <th id="T_430cf_level0_col2" class="col_heading level0 col2" >radius_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_430cf_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_430cf_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_430cf_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_430cf_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_430cf_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_430cf_row1_col0" class="data row1 col0" >12.146524</td>
#       <td id="T_430cf_row1_col1" class="data row1 col1" >0.284082</td>
#       <td id="T_430cf_row1_col2" class="data row1 col2" >13.379801</td>
#     </tr>
#     <tr>
#       <th id="T_430cf_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_430cf_row2_col0" class="data row2 col0" >1.780512</td>
#       <td id="T_430cf_row2_col1" class="data row2 col1" >0.112570</td>
#       <td id="T_430cf_row2_col2" class="data row2 col2" >1.981368</td>
#     </tr>
#     <tr>
#       <th id="T_430cf_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_430cf_row3_col0" class="data row3 col0" >6.981000</td>
#       <td id="T_430cf_row3_col1" class="data row3 col1" >0.111500</td>
#       <td id="T_430cf_row3_col2" class="data row3 col2" >7.930000</td>
#     </tr>
#     <tr>
#       <th id="T_430cf_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_430cf_row4_col0" class="data row4 col0" >11.080000</td>
#       <td id="T_430cf_row4_col1" class="data row4 col1" >0.207300</td>
#       <td id="T_430cf_row4_col2" class="data row4 col2" >12.080000</td>
#     </tr>
#     <tr>
#       <th id="T_430cf_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_430cf_row5_col0" class="data row5 col0" >12.200000</td>
#       <td id="T_430cf_row5_col1" class="data row5 col1" >0.257500</td>
#       <td id="T_430cf_row5_col2" class="data row5 col2" >13.350000</td>
#     </tr>
#     <tr>
#       <th id="T_430cf_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_430cf_row6_col0" class="data row6 col0" >13.370000</td>
#       <td id="T_430cf_row6_col1" class="data row6 col1" >0.341600</td>
#       <td id="T_430cf_row6_col2" class="data row6 col2" >14.800000</td>
#     </tr>
#     <tr>
#       <th id="T_430cf_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_430cf_row7_col0" class="data row7 col0" >17.850000</td>
#       <td id="T_430cf_row7_col1" class="data row7 col1" >0.881100</td>
#       <td id="T_430cf_row7_col2" class="data row7 col2" >19.820000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_e5258" style='display:inline'>
#   <caption>radius for M diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5258_level0_col0" class="col_heading level0 col0" >radius_mean</th>
#       <th id="T_e5258_level0_col1" class="col_heading level0 col1" >radius_se</th>
#       <th id="T_e5258_level0_col2" class="col_heading level0 col2" >radius_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5258_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_e5258_row0_col0" class="data row0 col0" >212.000000</td>
#       <td id="T_e5258_row0_col1" class="data row0 col1" >212.000000</td>
#       <td id="T_e5258_row0_col2" class="data row0 col2" >212.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e5258_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_e5258_row1_col0" class="data row1 col0" >17.462830</td>
#       <td id="T_e5258_row1_col1" class="data row1 col1" >0.609083</td>
#       <td id="T_e5258_row1_col2" class="data row1 col2" >21.134811</td>
#     </tr>
#     <tr>
#       <th id="T_e5258_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_e5258_row2_col0" class="data row2 col0" >3.203971</td>
#       <td id="T_e5258_row2_col1" class="data row2 col1" >0.345039</td>
#       <td id="T_e5258_row2_col2" class="data row2 col2" >4.283569</td>
#     </tr>
#     <tr>
#       <th id="T_e5258_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_e5258_row3_col0" class="data row3 col0" >10.950000</td>
#       <td id="T_e5258_row3_col1" class="data row3 col1" >0.193800</td>
#       <td id="T_e5258_row3_col2" class="data row3 col2" >12.840000</td>
#     </tr>
#     <tr>
#       <th id="T_e5258_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_e5258_row4_col0" class="data row4 col0" >15.075000</td>
#       <td id="T_e5258_row4_col1" class="data row4 col1" >0.390375</td>
#       <td id="T_e5258_row4_col2" class="data row4 col2" >17.730000</td>
#     </tr>
#     <tr>
#       <th id="T_e5258_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_e5258_row5_col0" class="data row5 col0" >17.325000</td>
#       <td id="T_e5258_row5_col1" class="data row5 col1" >0.547200</td>
#       <td id="T_e5258_row5_col2" class="data row5 col2" >20.590000</td>
#     </tr>
#     <tr>
#       <th id="T_e5258_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_e5258_row6_col0" class="data row6 col0" >19.590000</td>
#       <td id="T_e5258_row6_col1" class="data row6 col1" >0.757300</td>
#       <td id="T_e5258_row6_col2" class="data row6 col2" >23.807500</td>
#     </tr>
#     <tr>
#       <th id="T_e5258_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_e5258_row7_col0" class="data row7 col0" >28.110000</td>
#       <td id="T_e5258_row7_col1" class="data row7 col1" >2.873000</td>
#       <td id="T_e5258_row7_col2" class="data row7 col2" >36.040000</td>
#     </tr>
#   </tbody>
# </table>

# %%
texture_df=breast_cancer_df.loc[:, ["diagnosis", "texture_mean", "texture_se", "texture_worst"]]
texture_df.style.set_caption("texture for B diagnosis")

texture_B_df = texture_df[texture_df['diagnosis']=='B']
texture_M_df = texture_df[texture_df['diagnosis']=='M']

df1_styler = texture_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('texture for B diagnosis')
df2_styler = texture_M_df.describe().style.set_table_attributes("style='display:inline'").set_caption('texture for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_82d8c" style='display:inline'>
#   <caption>texture for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82d8c_level0_col0" class="col_heading level0 col0" >texture_mean</th>
#       <th id="T_82d8c_level0_col1" class="col_heading level0 col1" >texture_se</th>
#       <th id="T_82d8c_level0_col2" class="col_heading level0 col2" >texture_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82d8c_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_82d8c_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_82d8c_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_82d8c_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_82d8c_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_82d8c_row1_col0" class="data row1 col0" >17.914762</td>
#       <td id="T_82d8c_row1_col1" class="data row1 col1" >1.220380</td>
#       <td id="T_82d8c_row1_col2" class="data row1 col2" >23.515070</td>
#     </tr>
#     <tr>
#       <th id="T_82d8c_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_82d8c_row2_col0" class="data row2 col0" >3.995125</td>
#       <td id="T_82d8c_row2_col1" class="data row2 col1" >0.589180</td>
#       <td id="T_82d8c_row2_col2" class="data row2 col2" >5.493955</td>
#     </tr>
#     <tr>
#       <th id="T_82d8c_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_82d8c_row3_col0" class="data row3 col0" >9.710000</td>
#       <td id="T_82d8c_row3_col1" class="data row3 col1" >0.360200</td>
#       <td id="T_82d8c_row3_col2" class="data row3 col2" >12.020000</td>
#     </tr>
#     <tr>
#       <th id="T_82d8c_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_82d8c_row4_col0" class="data row4 col0" >15.150000</td>
#       <td id="T_82d8c_row4_col1" class="data row4 col1" >0.795900</td>
#       <td id="T_82d8c_row4_col2" class="data row4 col2" >19.580000</td>
#     </tr>
#     <tr>
#       <th id="T_82d8c_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_82d8c_row5_col0" class="data row5 col0" >17.390000</td>
#       <td id="T_82d8c_row5_col1" class="data row5 col1" >1.108000</td>
#       <td id="T_82d8c_row5_col2" class="data row5 col2" >22.820000</td>
#     </tr>
#     <tr>
#       <th id="T_82d8c_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_82d8c_row6_col0" class="data row6 col0" >19.760000</td>
#       <td id="T_82d8c_row6_col1" class="data row6 col1" >1.492000</td>
#       <td id="T_82d8c_row6_col2" class="data row6 col2" >26.510000</td>
#     </tr>
#     <tr>
#       <th id="T_82d8c_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_82d8c_row7_col0" class="data row7 col0" >33.810000</td>
#       <td id="T_82d8c_row7_col1" class="data row7 col1" >4.885000</td>
#       <td id="T_82d8c_row7_col2" class="data row7 col2" >41.780000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_c0507" style='display:inline'>
#   <caption>texture for M diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0507_level0_col0" class="col_heading level0 col0" >texture_mean</th>
#       <th id="T_c0507_level0_col1" class="col_heading level0 col1" >texture_se</th>
#       <th id="T_c0507_level0_col2" class="col_heading level0 col2" >texture_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0507_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_c0507_row0_col0" class="data row0 col0" >212.000000</td>
#       <td id="T_c0507_row0_col1" class="data row0 col1" >212.000000</td>
#       <td id="T_c0507_row0_col2" class="data row0 col2" >212.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c0507_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_c0507_row1_col0" class="data row1 col0" >21.604906</td>
#       <td id="T_c0507_row1_col1" class="data row1 col1" >1.210915</td>
#       <td id="T_c0507_row1_col2" class="data row1 col2" >29.318208</td>
#     </tr>
#     <tr>
#       <th id="T_c0507_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_c0507_row2_col0" class="data row2 col0" >3.779470</td>
#       <td id="T_c0507_row2_col1" class="data row2 col1" >0.483178</td>
#       <td id="T_c0507_row2_col2" class="data row2 col2" >5.434804</td>
#     </tr>
#     <tr>
#       <th id="T_c0507_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_c0507_row3_col0" class="data row3 col0" >10.380000</td>
#       <td id="T_c0507_row3_col1" class="data row3 col1" >0.362100</td>
#       <td id="T_c0507_row3_col2" class="data row3 col2" >16.670000</td>
#     </tr>
#     <tr>
#       <th id="T_c0507_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_c0507_row4_col0" class="data row4 col0" >19.327500</td>
#       <td id="T_c0507_row4_col1" class="data row4 col1" >0.892825</td>
#       <td id="T_c0507_row4_col2" class="data row4 col2" >25.782500</td>
#     </tr>
#     <tr>
#       <th id="T_c0507_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_c0507_row5_col0" class="data row5 col0" >21.460000</td>
#       <td id="T_c0507_row5_col1" class="data row5 col1" >1.102500</td>
#       <td id="T_c0507_row5_col2" class="data row5 col2" >28.945000</td>
#     </tr>
#     <tr>
#       <th id="T_c0507_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_c0507_row6_col0" class="data row6 col0" >23.765000</td>
#       <td id="T_c0507_row6_col1" class="data row6 col1" >1.429250</td>
#       <td id="T_c0507_row6_col2" class="data row6 col2" >32.690000</td>
#     </tr>
#     <tr>
#       <th id="T_c0507_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_c0507_row7_col0" class="data row7 col0" >39.280000</td>
#       <td id="T_c0507_row7_col1" class="data row7 col1" >3.568000</td>
#       <td id="T_c0507_row7_col2" class="data row7 col2" >49.540000</td>
#     </tr>
#   </tbody>
# </table>

# %%
perimeter_df=breast_cancer_df.loc[:, ["diagnosis", "perimeter_mean", "perimeter_se", "perimeter_worst"]]
perimeter_df.style.set_caption("perimeter for B diagnosis")

perimeter_B_df = perimeter_df[perimeter_df['diagnosis']=='B']
perimeter_M_df = perimeter_df[perimeter_df['diagnosis']=='M']

df1_styler = perimeter_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('perimeter for B diagnosis')
df2_styler = perimeter_M_df.describe().style.set_table_attributes("style='display:inline'").set_caption('perimeter for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_df02b" style='display:inline'>
#   <caption>perimeter for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df02b_level0_col0" class="col_heading level0 col0" >perimeter_mean</th>
#       <th id="T_df02b_level0_col1" class="col_heading level0 col1" >perimeter_se</th>
#       <th id="T_df02b_level0_col2" class="col_heading level0 col2" >perimeter_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df02b_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_df02b_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_df02b_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_df02b_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df02b_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_df02b_row1_col0" class="data row1 col0" >78.075406</td>
#       <td id="T_df02b_row1_col1" class="data row1 col1" >2.000321</td>
#       <td id="T_df02b_row1_col2" class="data row1 col2" >87.005938</td>
#     </tr>
#     <tr>
#       <th id="T_df02b_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_df02b_row2_col0" class="data row2 col0" >11.807438</td>
#       <td id="T_df02b_row2_col1" class="data row2 col1" >0.771169</td>
#       <td id="T_df02b_row2_col2" class="data row2 col2" >13.527091</td>
#     </tr>
#     <tr>
#       <th id="T_df02b_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_df02b_row3_col0" class="data row3 col0" >43.790000</td>
#       <td id="T_df02b_row3_col1" class="data row3 col1" >0.757000</td>
#       <td id="T_df02b_row3_col2" class="data row3 col2" >50.410000</td>
#     </tr>
#     <tr>
#       <th id="T_df02b_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_df02b_row4_col0" class="data row4 col0" >70.870000</td>
#       <td id="T_df02b_row4_col1" class="data row4 col1" >1.445000</td>
#       <td id="T_df02b_row4_col2" class="data row4 col2" >78.270000</td>
#     </tr>
#     <tr>
#       <th id="T_df02b_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_df02b_row5_col0" class="data row5 col0" >78.180000</td>
#       <td id="T_df02b_row5_col1" class="data row5 col1" >1.851000</td>
#       <td id="T_df02b_row5_col2" class="data row5 col2" >86.920000</td>
#     </tr>
#     <tr>
#       <th id="T_df02b_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_df02b_row6_col0" class="data row6 col0" >86.100000</td>
#       <td id="T_df02b_row6_col1" class="data row6 col1" >2.388000</td>
#       <td id="T_df02b_row6_col2" class="data row6 col2" >96.590000</td>
#     </tr>
#     <tr>
#       <th id="T_df02b_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_df02b_row7_col0" class="data row7 col0" >114.600000</td>
#       <td id="T_df02b_row7_col1" class="data row7 col1" >5.118000</td>
#       <td id="T_df02b_row7_col2" class="data row7 col2" >127.100000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_00466" style='display:inline'>
#   <caption>perimeter for M diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00466_level0_col0" class="col_heading level0 col0" >perimeter_mean</th>
#       <th id="T_00466_level0_col1" class="col_heading level0 col1" >perimeter_se</th>
#       <th id="T_00466_level0_col2" class="col_heading level0 col2" >perimeter_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00466_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_00466_row0_col0" class="data row0 col0" >212.000000</td>
#       <td id="T_00466_row0_col1" class="data row0 col1" >212.000000</td>
#       <td id="T_00466_row0_col2" class="data row0 col2" >212.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00466_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_00466_row1_col0" class="data row1 col0" >115.365377</td>
#       <td id="T_00466_row1_col1" class="data row1 col1" >4.323929</td>
#       <td id="T_00466_row1_col2" class="data row1 col2" >141.370330</td>
#     </tr>
#     <tr>
#       <th id="T_00466_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_00466_row2_col0" class="data row2 col0" >21.854653</td>
#       <td id="T_00466_row2_col1" class="data row2 col1" >2.568546</td>
#       <td id="T_00466_row2_col2" class="data row2 col2" >29.457055</td>
#     </tr>
#     <tr>
#       <th id="T_00466_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_00466_row3_col0" class="data row3 col0" >71.900000</td>
#       <td id="T_00466_row3_col1" class="data row3 col1" >1.334000</td>
#       <td id="T_00466_row3_col2" class="data row3 col2" >85.100000</td>
#     </tr>
#     <tr>
#       <th id="T_00466_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_00466_row4_col0" class="data row4 col0" >98.745000</td>
#       <td id="T_00466_row4_col1" class="data row4 col1" >2.715500</td>
#       <td id="T_00466_row4_col2" class="data row4 col2" >119.325000</td>
#     </tr>
#     <tr>
#       <th id="T_00466_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_00466_row5_col0" class="data row5 col0" >114.200000</td>
#       <td id="T_00466_row5_col1" class="data row5 col1" >3.679500</td>
#       <td id="T_00466_row5_col2" class="data row5 col2" >138.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00466_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_00466_row6_col0" class="data row6 col0" >129.925000</td>
#       <td id="T_00466_row6_col1" class="data row6 col1" >5.206250</td>
#       <td id="T_00466_row6_col2" class="data row6 col2" >159.800000</td>
#     </tr>
#     <tr>
#       <th id="T_00466_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_00466_row7_col0" class="data row7 col0" >188.500000</td>
#       <td id="T_00466_row7_col1" class="data row7 col1" >21.980000</td>
#       <td id="T_00466_row7_col2" class="data row7 col2" >251.200000</td>
#     </tr>
#   </tbody>
# </table>

# %%
area_df=breast_cancer_df.loc[:, ["diagnosis", "area_mean", "area_se", "area_worst"]]
area_df.style.set_caption("area for B diagnosis")

area_B_df = area_df[area_df['diagnosis']=='B']
area_M_df = area_df[area_df['diagnosis']=='M']

df1_styler = area_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('area for B diagnosis')
df2_styler = area_M_df.describe().style.set_table_attributes("style='display:inline'").set_caption('area for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_73fba" style='display:inline'>
#   <caption>area for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73fba_level0_col0" class="col_heading level0 col0" >area_mean</th>
#       <th id="T_73fba_level0_col1" class="col_heading level0 col1" >area_se</th>
#       <th id="T_73fba_level0_col2" class="col_heading level0 col2" >area_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73fba_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_73fba_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_73fba_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_73fba_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_73fba_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_73fba_row1_col0" class="data row1 col0" >462.790196</td>
#       <td id="T_73fba_row1_col1" class="data row1 col1" >21.135148</td>
#       <td id="T_73fba_row1_col2" class="data row1 col2" >558.899440</td>
#     </tr>
#     <tr>
#       <th id="T_73fba_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_73fba_row2_col0" class="data row2 col0" >134.287118</td>
#       <td id="T_73fba_row2_col1" class="data row2 col1" >8.843472</td>
#       <td id="T_73fba_row2_col2" class="data row2 col2" >163.601424</td>
#     </tr>
#     <tr>
#       <th id="T_73fba_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_73fba_row3_col0" class="data row3 col0" >143.500000</td>
#       <td id="T_73fba_row3_col1" class="data row3 col1" >6.802000</td>
#       <td id="T_73fba_row3_col2" class="data row3 col2" >185.200000</td>
#     </tr>
#     <tr>
#       <th id="T_73fba_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_73fba_row4_col0" class="data row4 col0" >378.200000</td>
#       <td id="T_73fba_row4_col1" class="data row4 col1" >15.260000</td>
#       <td id="T_73fba_row4_col2" class="data row4 col2" >447.100000</td>
#     </tr>
#     <tr>
#       <th id="T_73fba_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_73fba_row5_col0" class="data row5 col0" >458.400000</td>
#       <td id="T_73fba_row5_col1" class="data row5 col1" >19.630000</td>
#       <td id="T_73fba_row5_col2" class="data row5 col2" >547.400000</td>
#     </tr>
#     <tr>
#       <th id="T_73fba_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_73fba_row6_col0" class="data row6 col0" >551.100000</td>
#       <td id="T_73fba_row6_col1" class="data row6 col1" >25.030000</td>
#       <td id="T_73fba_row6_col2" class="data row6 col2" >670.000000</td>
#     </tr>
#     <tr>
#       <th id="T_73fba_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_73fba_row7_col0" class="data row7 col0" >992.100000</td>
#       <td id="T_73fba_row7_col1" class="data row7 col1" >77.110000</td>
#       <td id="T_73fba_row7_col2" class="data row7 col2" >1210.000000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_20380" style='display:inline'>
#   <caption>area for M diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20380_level0_col0" class="col_heading level0 col0" >area_mean</th>
#       <th id="T_20380_level0_col1" class="col_heading level0 col1" >area_se</th>
#       <th id="T_20380_level0_col2" class="col_heading level0 col2" >area_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20380_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_20380_row0_col0" class="data row0 col0" >212.000000</td>
#       <td id="T_20380_row0_col1" class="data row0 col1" >212.000000</td>
#       <td id="T_20380_row0_col2" class="data row0 col2" >212.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20380_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_20380_row1_col0" class="data row1 col0" >978.376415</td>
#       <td id="T_20380_row1_col1" class="data row1 col1" >72.672406</td>
#       <td id="T_20380_row1_col2" class="data row1 col2" >1422.286321</td>
#     </tr>
#     <tr>
#       <th id="T_20380_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_20380_row2_col0" class="data row2 col0" >367.937978</td>
#       <td id="T_20380_row2_col1" class="data row2 col1" >61.355268</td>
#       <td id="T_20380_row2_col2" class="data row2 col2" >597.967743</td>
#     </tr>
#     <tr>
#       <th id="T_20380_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_20380_row3_col0" class="data row3 col0" >361.600000</td>
#       <td id="T_20380_row3_col1" class="data row3 col1" >13.990000</td>
#       <td id="T_20380_row3_col2" class="data row3 col2" >508.100000</td>
#     </tr>
#     <tr>
#       <th id="T_20380_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_20380_row4_col0" class="data row4 col0" >705.300000</td>
#       <td id="T_20380_row4_col1" class="data row4 col1" >35.762500</td>
#       <td id="T_20380_row4_col2" class="data row4 col2" >970.300000</td>
#     </tr>
#     <tr>
#       <th id="T_20380_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_20380_row5_col0" class="data row5 col0" >932.000000</td>
#       <td id="T_20380_row5_col1" class="data row5 col1" >58.455000</td>
#       <td id="T_20380_row5_col2" class="data row5 col2" >1303.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20380_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_20380_row6_col0" class="data row6 col0" >1203.750000</td>
#       <td id="T_20380_row6_col1" class="data row6 col1" >94.000000</td>
#       <td id="T_20380_row6_col2" class="data row6 col2" >1712.750000</td>
#     </tr>
#     <tr>
#       <th id="T_20380_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_20380_row7_col0" class="data row7 col0" >2501.000000</td>
#       <td id="T_20380_row7_col1" class="data row7 col1" >542.200000</td>
#       <td id="T_20380_row7_col2" class="data row7 col2" >4254.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
smoothness_df=breast_cancer_df.loc[:, ["diagnosis", "smoothness_mean", "smoothness_se", "smoothness_worst"]]
smoothness_df.style.set_caption("smoothness for B diagnosis")

smoothness_B_df = smoothness_df[smoothness_df['diagnosis']=='B']
smoothness_M_df = smoothness_df[smoothness_df['diagnosis']=='M']

df1_styler = smoothness_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('smoothness for B diagnosis')
df2_styler = smoothness_M_df.describe().style.set_table_attributes("style='display:inline'").set_caption('smoothness for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8c34d" style='display:inline'>
#   <caption>smoothness for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c34d_level0_col0" class="col_heading level0 col0" >smoothness_mean</th>
#       <th id="T_8c34d_level0_col1" class="col_heading level0 col1" >smoothness_se</th>
#       <th id="T_8c34d_level0_col2" class="col_heading level0 col2" >smoothness_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c34d_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_8c34d_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_8c34d_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_8c34d_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8c34d_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_8c34d_row1_col0" class="data row1 col0" >0.092478</td>
#       <td id="T_8c34d_row1_col1" class="data row1 col1" >0.007196</td>
#       <td id="T_8c34d_row1_col2" class="data row1 col2" >0.124959</td>
#     </tr>
#     <tr>
#       <th id="T_8c34d_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_8c34d_row2_col0" class="data row2 col0" >0.013446</td>
#       <td id="T_8c34d_row2_col1" class="data row2 col1" >0.003061</td>
#       <td id="T_8c34d_row2_col2" class="data row2 col2" >0.020013</td>
#     </tr>
#     <tr>
#       <th id="T_8c34d_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_8c34d_row3_col0" class="data row3 col0" >0.052630</td>
#       <td id="T_8c34d_row3_col1" class="data row3 col1" >0.001713</td>
#       <td id="T_8c34d_row3_col2" class="data row3 col2" >0.071170</td>
#     </tr>
#     <tr>
#       <th id="T_8c34d_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_8c34d_row4_col0" class="data row4 col0" >0.083060</td>
#       <td id="T_8c34d_row4_col1" class="data row4 col1" >0.005212</td>
#       <td id="T_8c34d_row4_col2" class="data row4 col2" >0.110400</td>
#     </tr>
#     <tr>
#       <th id="T_8c34d_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_8c34d_row5_col0" class="data row5 col0" >0.090760</td>
#       <td id="T_8c34d_row5_col1" class="data row5 col1" >0.006530</td>
#       <td id="T_8c34d_row5_col2" class="data row5 col2" >0.125400</td>
#     </tr>
#     <tr>
#       <th id="T_8c34d_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_8c34d_row6_col0" class="data row6 col0" >0.100700</td>
#       <td id="T_8c34d_row6_col1" class="data row6 col1" >0.008534</td>
#       <td id="T_8c34d_row6_col2" class="data row6 col2" >0.137600</td>
#     </tr>
#     <tr>
#       <th id="T_8c34d_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_8c34d_row7_col0" class="data row7 col0" >0.163400</td>
#       <td id="T_8c34d_row7_col1" class="data row7 col1" >0.021770</td>
#       <td id="T_8c34d_row7_col2" class="data row7 col2" >0.200600</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_313dc" style='display:inline'>
#   <caption>smoothness for M diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_313dc_level0_col0" class="col_heading level0 col0" >smoothness_mean</th>
#       <th id="T_313dc_level0_col1" class="col_heading level0 col1" >smoothness_se</th>
#       <th id="T_313dc_level0_col2" class="col_heading level0 col2" >smoothness_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_313dc_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_313dc_row0_col0" class="data row0 col0" >212.000000</td>
#       <td id="T_313dc_row0_col1" class="data row0 col1" >212.000000</td>
#       <td id="T_313dc_row0_col2" class="data row0 col2" >212.000000</td>
#     </tr>
#     <tr>
#       <th id="T_313dc_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_313dc_row1_col0" class="data row1 col0" >0.102898</td>
#       <td id="T_313dc_row1_col1" class="data row1 col1" >0.006780</td>
#       <td id="T_313dc_row1_col2" class="data row1 col2" >0.144845</td>
#     </tr>
#     <tr>
#       <th id="T_313dc_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_313dc_row2_col0" class="data row2 col0" >0.012608</td>
#       <td id="T_313dc_row2_col1" class="data row2 col1" >0.002890</td>
#       <td id="T_313dc_row2_col2" class="data row2 col2" >0.021870</td>
#     </tr>
#     <tr>
#       <th id="T_313dc_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_313dc_row3_col0" class="data row3 col0" >0.073710</td>
#       <td id="T_313dc_row3_col1" class="data row3 col1" >0.002667</td>
#       <td id="T_313dc_row3_col2" class="data row3 col2" >0.088220</td>
#     </tr>
#     <tr>
#       <th id="T_313dc_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_313dc_row4_col0" class="data row4 col0" >0.094010</td>
#       <td id="T_313dc_row4_col1" class="data row4 col1" >0.005085</td>
#       <td id="T_313dc_row4_col2" class="data row4 col2" >0.130475</td>
#     </tr>
#     <tr>
#       <th id="T_313dc_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_313dc_row5_col0" class="data row5 col0" >0.102200</td>
#       <td id="T_313dc_row5_col1" class="data row5 col1" >0.006209</td>
#       <td id="T_313dc_row5_col2" class="data row5 col2" >0.143450</td>
#     </tr>
#     <tr>
#       <th id="T_313dc_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_313dc_row6_col0" class="data row6 col0" >0.110925</td>
#       <td id="T_313dc_row6_col1" class="data row6 col1" >0.007971</td>
#       <td id="T_313dc_row6_col2" class="data row6 col2" >0.155975</td>
#     </tr>
#     <tr>
#       <th id="T_313dc_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_313dc_row7_col0" class="data row7 col0" >0.144700</td>
#       <td id="T_313dc_row7_col1" class="data row7 col1" >0.031130</td>
#       <td id="T_313dc_row7_col2" class="data row7 col2" >0.222600</td>
#     </tr>
#   </tbody>
# </table>

# %%
compactness_df=breast_cancer_df.loc[:, ["diagnosis", "compactness_mean", "compactness_se", "compactness_worst"]]
compactness_df.style.set_caption("compactness for B diagnosis")

compactness_B_df = compactness_df[compactness_df['diagnosis']=='B']
compactness_M_df = compactness_df[compactness_df['diagnosis']=='M']

df1_styler = compactness_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('compactness for B diagnosis')
df2_styler = compactness_M_df.describe().style.set_table_attributes("style='display:inline'").set_caption('compactness for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fcbbd" style='display:inline'>
#   <caption>compactness for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcbbd_level0_col0" class="col_heading level0 col0" >compactness_mean</th>
#       <th id="T_fcbbd_level0_col1" class="col_heading level0 col1" >compactness_se</th>
#       <th id="T_fcbbd_level0_col2" class="col_heading level0 col2" >compactness_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcbbd_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_fcbbd_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_fcbbd_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_fcbbd_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fcbbd_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_fcbbd_row1_col0" class="data row1 col0" >0.080085</td>
#       <td id="T_fcbbd_row1_col1" class="data row1 col1" >0.021438</td>
#       <td id="T_fcbbd_row1_col2" class="data row1 col2" >0.182673</td>
#     </tr>
#     <tr>
#       <th id="T_fcbbd_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_fcbbd_row2_col0" class="data row2 col0" >0.033750</td>
#       <td id="T_fcbbd_row2_col1" class="data row2 col1" >0.016352</td>
#       <td id="T_fcbbd_row2_col2" class="data row2 col2" >0.092180</td>
#     </tr>
#     <tr>
#       <th id="T_fcbbd_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_fcbbd_row3_col0" class="data row3 col0" >0.019380</td>
#       <td id="T_fcbbd_row3_col1" class="data row3 col1" >0.002252</td>
#       <td id="T_fcbbd_row3_col2" class="data row3 col2" >0.027290</td>
#     </tr>
#     <tr>
#       <th id="T_fcbbd_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_fcbbd_row4_col0" class="data row4 col0" >0.055620</td>
#       <td id="T_fcbbd_row4_col1" class="data row4 col1" >0.011320</td>
#       <td id="T_fcbbd_row4_col2" class="data row4 col2" >0.112000</td>
#     </tr>
#     <tr>
#       <th id="T_fcbbd_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_fcbbd_row5_col0" class="data row5 col0" >0.075290</td>
#       <td id="T_fcbbd_row5_col1" class="data row5 col1" >0.016310</td>
#       <td id="T_fcbbd_row5_col2" class="data row5 col2" >0.169800</td>
#     </tr>
#     <tr>
#       <th id="T_fcbbd_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_fcbbd_row6_col0" class="data row6 col0" >0.097550</td>
#       <td id="T_fcbbd_row6_col1" class="data row6 col1" >0.025890</td>
#       <td id="T_fcbbd_row6_col2" class="data row6 col2" >0.230200</td>
#     </tr>
#     <tr>
#       <th id="T_fcbbd_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_fcbbd_row7_col0" class="data row7 col0" >0.223900</td>
#       <td id="T_fcbbd_row7_col1" class="data row7 col1" >0.106400</td>
#       <td id="T_fcbbd_row7_col2" class="data row7 col2" >0.584900</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ddd42" style='display:inline'>
#   <caption>compactness for M diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddd42_level0_col0" class="col_heading level0 col0" >compactness_mean</th>
#       <th id="T_ddd42_level0_col1" class="col_heading level0 col1" >compactness_se</th>
#       <th id="T_ddd42_level0_col2" class="col_heading level0 col2" >compactness_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddd42_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_ddd42_row0_col0" class="data row0 col0" >212.000000</td>
#       <td id="T_ddd42_row0_col1" class="data row0 col1" >212.000000</td>
#       <td id="T_ddd42_row0_col2" class="data row0 col2" >212.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ddd42_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_ddd42_row1_col0" class="data row1 col0" >0.145188</td>
#       <td id="T_ddd42_row1_col1" class="data row1 col1" >0.032281</td>
#       <td id="T_ddd42_row1_col2" class="data row1 col2" >0.374824</td>
#     </tr>
#     <tr>
#       <th id="T_ddd42_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_ddd42_row2_col0" class="data row2 col0" >0.053987</td>
#       <td id="T_ddd42_row2_col1" class="data row2 col1" >0.018387</td>
#       <td id="T_ddd42_row2_col2" class="data row2 col2" >0.170372</td>
#     </tr>
#     <tr>
#       <th id="T_ddd42_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_ddd42_row3_col0" class="data row3 col0" >0.046050</td>
#       <td id="T_ddd42_row3_col1" class="data row3 col1" >0.008422</td>
#       <td id="T_ddd42_row3_col2" class="data row3 col2" >0.051310</td>
#     </tr>
#     <tr>
#       <th id="T_ddd42_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_ddd42_row4_col0" class="data row4 col0" >0.109600</td>
#       <td id="T_ddd42_row4_col1" class="data row4 col1" >0.019662</td>
#       <td id="T_ddd42_row4_col2" class="data row4 col2" >0.244475</td>
#     </tr>
#     <tr>
#       <th id="T_ddd42_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_ddd42_row5_col0" class="data row5 col0" >0.132350</td>
#       <td id="T_ddd42_row5_col1" class="data row5 col1" >0.028590</td>
#       <td id="T_ddd42_row5_col2" class="data row5 col2" >0.356350</td>
#     </tr>
#     <tr>
#       <th id="T_ddd42_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_ddd42_row6_col0" class="data row6 col0" >0.172400</td>
#       <td id="T_ddd42_row6_col1" class="data row6 col1" >0.038910</td>
#       <td id="T_ddd42_row6_col2" class="data row6 col2" >0.447850</td>
#     </tr>
#     <tr>
#       <th id="T_ddd42_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_ddd42_row7_col0" class="data row7 col0" >0.345400</td>
#       <td id="T_ddd42_row7_col1" class="data row7 col1" >0.135400</td>
#       <td id="T_ddd42_row7_col2" class="data row7 col2" >1.058000</td>
#     </tr>
#   </tbody>
# </table>

# %%
concavity_df=breast_cancer_df.loc[:, ["diagnosis", "concavity_mean", "concavity_se", "concavity_worst"]]
concavity_df.style.set_caption("concavity for B diagnosis")

concavity_B_df = concavity_df[concavity_df['diagnosis']=='B']
concavity_M_df = concavity_df[concavity_df['diagnosis']=='M']

df1_styler = concavity_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('concavity for B diagnosis')
df2_styler = concavity_M_df.describe().style.set_table_attributes("style='display:inline'").set_caption('concavity for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_12031" style='display:inline'>
#   <caption>concavity for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12031_level0_col0" class="col_heading level0 col0" >concavity_mean</th>
#       <th id="T_12031_level0_col1" class="col_heading level0 col1" >concavity_se</th>
#       <th id="T_12031_level0_col2" class="col_heading level0 col2" >concavity_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12031_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_12031_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_12031_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_12031_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12031_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_12031_row1_col0" class="data row1 col0" >0.046058</td>
#       <td id="T_12031_row1_col1" class="data row1 col1" >0.025997</td>
#       <td id="T_12031_row1_col2" class="data row1 col2" >0.166238</td>
#     </tr>
#     <tr>
#       <th id="T_12031_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_12031_row2_col0" class="data row2 col0" >0.043442</td>
#       <td id="T_12031_row2_col1" class="data row2 col1" >0.032918</td>
#       <td id="T_12031_row2_col2" class="data row2 col2" >0.140368</td>
#     </tr>
#     <tr>
#       <th id="T_12031_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_12031_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_12031_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_12031_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12031_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_12031_row4_col0" class="data row4 col0" >0.020310</td>
#       <td id="T_12031_row4_col1" class="data row4 col1" >0.010990</td>
#       <td id="T_12031_row4_col2" class="data row4 col2" >0.077080</td>
#     </tr>
#     <tr>
#       <th id="T_12031_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_12031_row5_col0" class="data row5 col0" >0.037090</td>
#       <td id="T_12031_row5_col1" class="data row5 col1" >0.018400</td>
#       <td id="T_12031_row5_col2" class="data row5 col2" >0.141200</td>
#     </tr>
#     <tr>
#       <th id="T_12031_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_12031_row6_col0" class="data row6 col0" >0.059990</td>
#       <td id="T_12031_row6_col1" class="data row6 col1" >0.030560</td>
#       <td id="T_12031_row6_col2" class="data row6 col2" >0.221600</td>
#     </tr>
#     <tr>
#       <th id="T_12031_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_12031_row7_col0" class="data row7 col0" >0.410800</td>
#       <td id="T_12031_row7_col1" class="data row7 col1" >0.396000</td>
#       <td id="T_12031_row7_col2" class="data row7 col2" >1.252000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_2df68" style='display:inline'>
#   <caption>concavity for M diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2df68_level0_col0" class="col_heading level0 col0" >concavity_mean</th>
#       <th id="T_2df68_level0_col1" class="col_heading level0 col1" >concavity_se</th>
#       <th id="T_2df68_level0_col2" class="col_heading level0 col2" >concavity_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2df68_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_2df68_row0_col0" class="data row0 col0" >212.000000</td>
#       <td id="T_2df68_row0_col1" class="data row0 col1" >212.000000</td>
#       <td id="T_2df68_row0_col2" class="data row0 col2" >212.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2df68_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_2df68_row1_col0" class="data row1 col0" >0.160775</td>
#       <td id="T_2df68_row1_col1" class="data row1 col1" >0.041824</td>
#       <td id="T_2df68_row1_col2" class="data row1 col2" >0.450606</td>
#     </tr>
#     <tr>
#       <th id="T_2df68_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_2df68_row2_col0" class="data row2 col0" >0.075019</td>
#       <td id="T_2df68_row2_col1" class="data row2 col1" >0.021603</td>
#       <td id="T_2df68_row2_col2" class="data row2 col2" >0.181507</td>
#     </tr>
#     <tr>
#       <th id="T_2df68_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_2df68_row3_col0" class="data row3 col0" >0.023980</td>
#       <td id="T_2df68_row3_col1" class="data row3 col1" >0.011010</td>
#       <td id="T_2df68_row3_col2" class="data row3 col2" >0.023980</td>
#     </tr>
#     <tr>
#       <th id="T_2df68_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_2df68_row4_col0" class="data row4 col0" >0.109525</td>
#       <td id="T_2df68_row4_col1" class="data row4 col1" >0.026998</td>
#       <td id="T_2df68_row4_col2" class="data row4 col2" >0.326425</td>
#     </tr>
#     <tr>
#       <th id="T_2df68_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_2df68_row5_col0" class="data row5 col0" >0.151350</td>
#       <td id="T_2df68_row5_col1" class="data row5 col1" >0.037125</td>
#       <td id="T_2df68_row5_col2" class="data row5 col2" >0.404900</td>
#     </tr>
#     <tr>
#       <th id="T_2df68_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_2df68_row6_col0" class="data row6 col0" >0.203050</td>
#       <td id="T_2df68_row6_col1" class="data row6 col1" >0.050443</td>
#       <td id="T_2df68_row6_col2" class="data row6 col2" >0.556175</td>
#     </tr>
#     <tr>
#       <th id="T_2df68_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_2df68_row7_col0" class="data row7 col0" >0.426800</td>
#       <td id="T_2df68_row7_col1" class="data row7 col1" >0.143800</td>
#       <td id="T_2df68_row7_col2" class="data row7 col2" >1.170000</td>
#     </tr>
#   </tbody>
# </table>

# %%
concave_points_df=breast_cancer_df.loc[:, ["diagnosis", "concave points_mean", "concave points_se", "concave points_worst"]]
concave_points_df.style.set_caption("concave points for B diagnosis")

concave_points_B_df = concave_points_df[concave_points_df['diagnosis']=='B']
concave_points_M_df = concave_points_df[concave_points_df['diagnosis']=='M']

df1_styler = concave_points_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('concave points for B diagnosis')
df2_styler = concave_points_M_df.describe().style.set_table_attributes("style='display:inline'").set_caption('concave points for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_eba4a" style='display:inline'>
#   <caption>concave points for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eba4a_level0_col0" class="col_heading level0 col0" >concave points_mean</th>
#       <th id="T_eba4a_level0_col1" class="col_heading level0 col1" >concave points_se</th>
#       <th id="T_eba4a_level0_col2" class="col_heading level0 col2" >concave points_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eba4a_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_eba4a_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_eba4a_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_eba4a_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eba4a_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_eba4a_row1_col0" class="data row1 col0" >0.025717</td>
#       <td id="T_eba4a_row1_col1" class="data row1 col1" >0.009858</td>
#       <td id="T_eba4a_row1_col2" class="data row1 col2" >0.074444</td>
#     </tr>
#     <tr>
#       <th id="T_eba4a_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_eba4a_row2_col0" class="data row2 col0" >0.015909</td>
#       <td id="T_eba4a_row2_col1" class="data row2 col1" >0.005709</td>
#       <td id="T_eba4a_row2_col2" class="data row2 col2" >0.035797</td>
#     </tr>
#     <tr>
#       <th id="T_eba4a_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_eba4a_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_eba4a_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_eba4a_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eba4a_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_eba4a_row4_col0" class="data row4 col0" >0.015020</td>
#       <td id="T_eba4a_row4_col1" class="data row4 col1" >0.006433</td>
#       <td id="T_eba4a_row4_col2" class="data row4 col2" >0.051040</td>
#     </tr>
#     <tr>
#       <th id="T_eba4a_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_eba4a_row5_col0" class="data row5 col0" >0.023440</td>
#       <td id="T_eba4a_row5_col1" class="data row5 col1" >0.009061</td>
#       <td id="T_eba4a_row5_col2" class="data row5 col2" >0.074310</td>
#     </tr>
#     <tr>
#       <th id="T_eba4a_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_eba4a_row6_col0" class="data row6 col0" >0.032510</td>
#       <td id="T_eba4a_row6_col1" class="data row6 col1" >0.011870</td>
#       <td id="T_eba4a_row6_col2" class="data row6 col2" >0.097490</td>
#     </tr>
#     <tr>
#       <th id="T_eba4a_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_eba4a_row7_col0" class="data row7 col0" >0.085340</td>
#       <td id="T_eba4a_row7_col1" class="data row7 col1" >0.052790</td>
#       <td id="T_eba4a_row7_col2" class="data row7 col2" >0.175000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_dac52" style='display:inline'>
#   <caption>concave points for M diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dac52_level0_col0" class="col_heading level0 col0" >concave points_mean</th>
#       <th id="T_dac52_level0_col1" class="col_heading level0 col1" >concave points_se</th>
#       <th id="T_dac52_level0_col2" class="col_heading level0 col2" >concave points_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dac52_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_dac52_row0_col0" class="data row0 col0" >212.000000</td>
#       <td id="T_dac52_row0_col1" class="data row0 col1" >212.000000</td>
#       <td id="T_dac52_row0_col2" class="data row0 col2" >212.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dac52_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_dac52_row1_col0" class="data row1 col0" >0.087990</td>
#       <td id="T_dac52_row1_col1" class="data row1 col1" >0.015060</td>
#       <td id="T_dac52_row1_col2" class="data row1 col2" >0.182237</td>
#     </tr>
#     <tr>
#       <th id="T_dac52_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_dac52_row2_col0" class="data row2 col0" >0.034374</td>
#       <td id="T_dac52_row2_col1" class="data row2 col1" >0.005517</td>
#       <td id="T_dac52_row2_col2" class="data row2 col2" >0.046308</td>
#     </tr>
#     <tr>
#       <th id="T_dac52_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_dac52_row3_col0" class="data row3 col0" >0.020310</td>
#       <td id="T_dac52_row3_col1" class="data row3 col1" >0.005174</td>
#       <td id="T_dac52_row3_col2" class="data row3 col2" >0.028990</td>
#     </tr>
#     <tr>
#       <th id="T_dac52_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_dac52_row4_col0" class="data row4 col0" >0.064620</td>
#       <td id="T_dac52_row4_col1" class="data row4 col1" >0.011415</td>
#       <td id="T_dac52_row4_col2" class="data row4 col2" >0.152750</td>
#     </tr>
#     <tr>
#       <th id="T_dac52_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_dac52_row5_col0" class="data row5 col0" >0.086280</td>
#       <td id="T_dac52_row5_col1" class="data row5 col1" >0.014205</td>
#       <td id="T_dac52_row5_col2" class="data row5 col2" >0.182000</td>
#     </tr>
#     <tr>
#       <th id="T_dac52_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_dac52_row6_col0" class="data row6 col0" >0.103175</td>
#       <td id="T_dac52_row6_col1" class="data row6 col1" >0.017497</td>
#       <td id="T_dac52_row6_col2" class="data row6 col2" >0.210675</td>
#     </tr>
#     <tr>
#       <th id="T_dac52_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_dac52_row7_col0" class="data row7 col0" >0.201200</td>
#       <td id="T_dac52_row7_col1" class="data row7 col1" >0.040900</td>
#       <td id="T_dac52_row7_col2" class="data row7 col2" >0.291000</td>
#     </tr>
#   </tbody>
# </table>

# %%
symmetry_df=breast_cancer_df.loc[:, ["diagnosis", "symmetry_mean", "symmetry_se", "symmetry_worst"]]
symmetry_df.style.set_caption("symmetry for B diagnosis")

symmetry_B_df = symmetry_df[symmetry_df['diagnosis']=='B']
symmetry_M_df = symmetry_df[symmetry_df['diagnosis']=='M']

df1_styler = symmetry_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('symmetry for B diagnosis')
df2_styler = symmetry_M_df.describe().style.set_table_attributes("style='display:inline'").set_caption('symmetry for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d07e8" style='display:inline'>
#   <caption>symmetry for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d07e8_level0_col0" class="col_heading level0 col0" >symmetry_mean</th>
#       <th id="T_d07e8_level0_col1" class="col_heading level0 col1" >symmetry_se</th>
#       <th id="T_d07e8_level0_col2" class="col_heading level0 col2" >symmetry_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d07e8_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_d07e8_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_d07e8_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_d07e8_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d07e8_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_d07e8_row1_col0" class="data row1 col0" >0.174186</td>
#       <td id="T_d07e8_row1_col1" class="data row1 col1" >0.020584</td>
#       <td id="T_d07e8_row1_col2" class="data row1 col2" >0.270246</td>
#     </tr>
#     <tr>
#       <th id="T_d07e8_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_d07e8_row2_col0" class="data row2 col0" >0.024807</td>
#       <td id="T_d07e8_row2_col1" class="data row2 col1" >0.006999</td>
#       <td id="T_d07e8_row2_col2" class="data row2 col2" >0.041745</td>
#     </tr>
#     <tr>
#       <th id="T_d07e8_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_d07e8_row3_col0" class="data row3 col0" >0.106000</td>
#       <td id="T_d07e8_row3_col1" class="data row3 col1" >0.009539</td>
#       <td id="T_d07e8_row3_col2" class="data row3 col2" >0.156600</td>
#     </tr>
#     <tr>
#       <th id="T_d07e8_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_d07e8_row4_col0" class="data row4 col0" >0.158000</td>
#       <td id="T_d07e8_row4_col1" class="data row4 col1" >0.015600</td>
#       <td id="T_d07e8_row4_col2" class="data row4 col2" >0.240600</td>
#     </tr>
#     <tr>
#       <th id="T_d07e8_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_d07e8_row5_col0" class="data row5 col0" >0.171400</td>
#       <td id="T_d07e8_row5_col1" class="data row5 col1" >0.019090</td>
#       <td id="T_d07e8_row5_col2" class="data row5 col2" >0.268700</td>
#     </tr>
#     <tr>
#       <th id="T_d07e8_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_d07e8_row6_col0" class="data row6 col0" >0.189000</td>
#       <td id="T_d07e8_row6_col1" class="data row6 col1" >0.024060</td>
#       <td id="T_d07e8_row6_col2" class="data row6 col2" >0.298300</td>
#     </tr>
#     <tr>
#       <th id="T_d07e8_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_d07e8_row7_col0" class="data row7 col0" >0.274300</td>
#       <td id="T_d07e8_row7_col1" class="data row7 col1" >0.061460</td>
#       <td id="T_d07e8_row7_col2" class="data row7 col2" >0.422800</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_5fdea" style='display:inline'>
#   <caption>symmetry for M diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fdea_level0_col0" class="col_heading level0 col0" >symmetry_mean</th>
#       <th id="T_5fdea_level0_col1" class="col_heading level0 col1" >symmetry_se</th>
#       <th id="T_5fdea_level0_col2" class="col_heading level0 col2" >symmetry_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fdea_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_5fdea_row0_col0" class="data row0 col0" >212.000000</td>
#       <td id="T_5fdea_row0_col1" class="data row0 col1" >212.000000</td>
#       <td id="T_5fdea_row0_col2" class="data row0 col2" >212.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5fdea_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_5fdea_row1_col0" class="data row1 col0" >0.192909</td>
#       <td id="T_5fdea_row1_col1" class="data row1 col1" >0.020472</td>
#       <td id="T_5fdea_row1_col2" class="data row1 col2" >0.323468</td>
#     </tr>
#     <tr>
#       <th id="T_5fdea_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_5fdea_row2_col0" class="data row2 col0" >0.027638</td>
#       <td id="T_5fdea_row2_col1" class="data row2 col1" >0.010065</td>
#       <td id="T_5fdea_row2_col2" class="data row2 col2" >0.074685</td>
#     </tr>
#     <tr>
#       <th id="T_5fdea_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_5fdea_row3_col0" class="data row3 col0" >0.130800</td>
#       <td id="T_5fdea_row3_col1" class="data row3 col1" >0.007882</td>
#       <td id="T_5fdea_row3_col2" class="data row3 col2" >0.156500</td>
#     </tr>
#     <tr>
#       <th id="T_5fdea_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_5fdea_row4_col0" class="data row4 col0" >0.174050</td>
#       <td id="T_5fdea_row4_col1" class="data row4 col1" >0.014615</td>
#       <td id="T_5fdea_row4_col2" class="data row4 col2" >0.276500</td>
#     </tr>
#     <tr>
#       <th id="T_5fdea_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_5fdea_row5_col0" class="data row5 col0" >0.189900</td>
#       <td id="T_5fdea_row5_col1" class="data row5 col1" >0.017700</td>
#       <td id="T_5fdea_row5_col2" class="data row5 col2" >0.310300</td>
#     </tr>
#     <tr>
#       <th id="T_5fdea_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_5fdea_row6_col0" class="data row6 col0" >0.209850</td>
#       <td id="T_5fdea_row6_col1" class="data row6 col1" >0.022132</td>
#       <td id="T_5fdea_row6_col2" class="data row6 col2" >0.359225</td>
#     </tr>
#     <tr>
#       <th id="T_5fdea_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_5fdea_row7_col0" class="data row7 col0" >0.304000</td>
#       <td id="T_5fdea_row7_col1" class="data row7 col1" >0.078950</td>
#       <td id="T_5fdea_row7_col2" class="data row7 col2" >0.663800</td>
#     </tr>
#   </tbody>
# </table>

# %%
fractal_dimension_df=breast_cancer_df.loc[:, ["diagnosis", "fractal_dimension_mean", "fractal_dimension_se", "fractal_dimension_worst"]]
fractal_dimension_df.style.set_caption("fractal_dimension for B diagnosis")

fractal_dimension_B_df = fractal_dimension_df[fractal_dimension_df['diagnosis']=='B']
fractal_dimension_M_df = fractal_dimension_df[fractal_dimension_df['diagnosis']=='M']

df1_styler = fractal_dimension_B_df.describe().style.set_table_attributes("style='display:inline'").set_caption('fractal_dimension for B diagnosis')
df2_styler = fractal_dimension_M_df.style.set_table_attributes("style='display:inline'").set_caption('fractal_dimension for M diagnosis')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d42af" style='display:inline'>
#   <caption>fractal_dimension for B diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d42af_level0_col0" class="col_heading level0 col0" >fractal_dimension_mean</th>
#       <th id="T_d42af_level0_col1" class="col_heading level0 col1" >fractal_dimension_se</th>
#       <th id="T_d42af_level0_col2" class="col_heading level0 col2" >fractal_dimension_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d42af_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_d42af_row0_col0" class="data row0 col0" >357.000000</td>
#       <td id="T_d42af_row0_col1" class="data row0 col1" >357.000000</td>
#       <td id="T_d42af_row0_col2" class="data row0 col2" >357.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d42af_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_d42af_row1_col0" class="data row1 col0" >0.062867</td>
#       <td id="T_d42af_row1_col1" class="data row1 col1" >0.003636</td>
#       <td id="T_d42af_row1_col2" class="data row1 col2" >0.079442</td>
#     </tr>
#     <tr>
#       <th id="T_d42af_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_d42af_row2_col0" class="data row2 col0" >0.006747</td>
#       <td id="T_d42af_row2_col1" class="data row2 col1" >0.002938</td>
#       <td id="T_d42af_row2_col2" class="data row2 col2" >0.013804</td>
#     </tr>
#     <tr>
#       <th id="T_d42af_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_d42af_row3_col0" class="data row3 col0" >0.051850</td>
#       <td id="T_d42af_row3_col1" class="data row3 col1" >0.000895</td>
#       <td id="T_d42af_row3_col2" class="data row3 col2" >0.055210</td>
#     </tr>
#     <tr>
#       <th id="T_d42af_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_d42af_row4_col0" class="data row4 col0" >0.058530</td>
#       <td id="T_d42af_row4_col1" class="data row4 col1" >0.002074</td>
#       <td id="T_d42af_row4_col2" class="data row4 col2" >0.070090</td>
#     </tr>
#     <tr>
#       <th id="T_d42af_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_d42af_row5_col0" class="data row5 col0" >0.061540</td>
#       <td id="T_d42af_row5_col1" class="data row5 col1" >0.002808</td>
#       <td id="T_d42af_row5_col2" class="data row5 col2" >0.077120</td>
#     </tr>
#     <tr>
#       <th id="T_d42af_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_d42af_row6_col0" class="data row6 col0" >0.065760</td>
#       <td id="T_d42af_row6_col1" class="data row6 col1" >0.004174</td>
#       <td id="T_d42af_row6_col2" class="data row6 col2" >0.085410</td>
#     </tr>
#     <tr>
#       <th id="T_d42af_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_d42af_row7_col0" class="data row7 col0" >0.095750</td>
#       <td id="T_d42af_row7_col1" class="data row7 col1" >0.029840</td>
#       <td id="T_d42af_row7_col2" class="data row7 col2" >0.148600</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_b9f84" style='display:inline'>
#   <caption>fractal_dimension for M diagnosis</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9f84_level0_col0" class="col_heading level0 col0" >fractal_dimension_mean</th>
#       <th id="T_b9f84_level0_col1" class="col_heading level0 col1" >fractal_dimension_se</th>
#       <th id="T_b9f84_level0_col2" class="col_heading level0 col2" >fractal_dimension_worst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9f84_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_b9f84_row0_col0" class="data row0 col0" >212.000000</td>
#       <td id="T_b9f84_row0_col1" class="data row0 col1" >212.000000</td>
#       <td id="T_b9f84_row0_col2" class="data row0 col2" >212.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b9f84_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_b9f84_row1_col0" class="data row1 col0" >0.062680</td>
#       <td id="T_b9f84_row1_col1" class="data row1 col1" >0.004062</td>
#       <td id="T_b9f84_row1_col2" class="data row1 col2" >0.091530</td>
#     </tr>
#     <tr>
#       <th id="T_b9f84_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_b9f84_row2_col0" class="data row2 col0" >0.007573</td>
#       <td id="T_b9f84_row2_col1" class="data row2 col1" >0.002041</td>
#       <td id="T_b9f84_row2_col2" class="data row2 col2" >0.021553</td>
#     </tr>
#     <tr>
#       <th id="T_b9f84_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_b9f84_row3_col0" class="data row3 col0" >0.049960</td>
#       <td id="T_b9f84_row3_col1" class="data row3 col1" >0.001087</td>
#       <td id="T_b9f84_row3_col2" class="data row3 col2" >0.055040</td>
#     </tr>
#     <tr>
#       <th id="T_b9f84_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_b9f84_row4_col0" class="data row4 col0" >0.056598</td>
#       <td id="T_b9f84_row4_col1" class="data row4 col1" >0.002688</td>
#       <td id="T_b9f84_row4_col2" class="data row4 col2" >0.076302</td>
#     </tr>
#     <tr>
#       <th id="T_b9f84_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_b9f84_row5_col0" class="data row5 col0" >0.061575</td>
#       <td id="T_b9f84_row5_col1" class="data row5 col1" >0.003739</td>
#       <td id="T_b9f84_row5_col2" class="data row5 col2" >0.087600</td>
#     </tr>
#     <tr>
#       <th id="T_b9f84_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_b9f84_row6_col0" class="data row6 col0" >0.067075</td>
#       <td id="T_b9f84_row6_col1" class="data row6 col1" >0.004892</td>
#       <td id="T_b9f84_row6_col2" class="data row6 col2" >0.102625</td>
#     </tr>
#     <tr>
#       <th id="T_b9f84_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_b9f84_row7_col0" class="data row7 col0" >0.097440</td>
#       <td id="T_b9f84_row7_col1" class="data row7 col1" >0.012840</td>
#       <td id="T_b9f84_row7_col2" class="data row7 col2" >0.207500</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(f'ratio rayon moyen M par rapport à rayon moyen B : {int(radius_M_df["radius_mean"].mean()/radius_B_df["radius_mean"].mean()*100)} %')
print(f'ratio texture moyen M par rapport à texture moyen B : {int(texture_M_df["texture_mean"].mean()/texture_B_df["texture_mean"].mean()*100)} %')
print(f'ratio périmètre moyen  M par rapport à périmètre moyen B : {int(perimeter_M_df["perimeter_mean"].mean()/perimeter_B_df["perimeter_mean"].mean()*100)} %')
print(f'ratio aire moyen M par rapport à aire moyen B : {int(area_M_df["area_mean"].mean()/area_B_df["area_mean"].mean()*100)} %')
print(f'ratio smoothness moyen M par rapport à smoothness moyen B : {int(smoothness_M_df["smoothness_mean"].mean()/smoothness_B_df["smoothness_mean"].mean()*100)} %')
print(f'ratio compactness moyen M par rapport à compactness moyen B : {int(compactness_M_df["compactness_mean"].mean()/compactness_B_df["compactness_mean"].mean()*100)}%')
print(f'ratio de concavité moyen M par rapport à de concavité moyen B : {int(concavity_M_df["concavity_mean"].mean()/concavity_B_df["concavity_mean"].mean()*100)}%')
print(f'ratio points concaves M moyen par rapport à points concaves moyen B : {int(concave_points_M_df["concave points_mean"].mean()/concave_points_B_df["concave points_mean"].mean()*100)}%')
print(f'ratio symétrie moyen M par rapport à symétrie moyen B : {int(symmetry_M_df["symmetry_mean"].mean()/symmetry_B_df["symmetry_mean"].mean()*100)}%')
print(f'ratio fractal dimension moyen M par rapport à fractal dimension moyen B : {int(fractal_dimension_M_df["fractal_dimension_mean"].mean()/fractal_dimension_B_df["fractal_dimension_mean"].mean()*100)}%')
# Out:
# ratio rayon moyen M par rapport à rayon moyen B : 143 %
# ratio texture moyen M par rapport à texture moyen B : 120 %
# ratio périmètre moyen  M par rapport à périmètre moyen B : 147 %
# ratio aire moyen M par rapport à aire moyen B : 211 %
# ratio smoothness moyen M par rapport à smoothness moyen B : 111 %
# ratio compactness moyen M par rapport à compactness moyen B : 181%
# ratio de concavité moyen M par rapport à de concavité moyen B : 349%
# ratio points concaves M moyen par rapport à points concaves moyen B : 342%
# ratio symétrie moyen M par rapport à symétrie moyen B : 110%
# ratio fractal dimension moyen M par rapport à fractal dimension moyen B : 99%

# %%
print(f'ratio worst rayon M par rapport à worst rayon B : {int(radius_M_df["radius_worst"].mean()/radius_B_df["radius_worst"].mean()*100)} %')
print(f'ratio worst texture M par rapport à worst texture B : {int(texture_M_df["texture_worst"].mean()/texture_B_df["texture_worst"].mean()*100)} %')
print(f'ratio worst périmètre M par rapport à worst périmètre B : {int(perimeter_M_df["perimeter_worst"].mean()/perimeter_B_df["perimeter_worst"].mean()*100)} %')
print(f'ratio worst aire M par rapport à worst aire B : {int(area_M_df["area_worst"].mean()/area_B_df["area_worst"].mean()*100)} %')
print(f'ratio worst smoothness M par rapport à worst smoothness B : {int(smoothness_M_df["smoothness_worst"].mean()/smoothness_B_df["smoothness_worst"].mean()*100)} %')
print(f'ratio worst compactness M par rapport à worst compactness B : {int(compactness_M_df["compactness_worst"].mean()/compactness_B_df["compactness_worst"].mean()*100)}%')
print(f'ratio worst concavité M par rapport à worst concavité B : {int(concavity_M_df["concavity_worst"].mean()/concavity_B_df["concavity_worst"].mean()*100)}%')
print(f'ratio worst points concaves M par rapport à worst points concaves B : {int(concave_points_M_df["concave points_worst"].mean()/concave_points_B_df["concave points_worst"].mean()*100)}%')
print(f'ratio sworst ymétrie M par rapport à worst symétrie B : {int(symmetry_M_df["symmetry_worst"].mean()/symmetry_B_df["symmetry_worst"].mean()*100)}%')
print(f'ratio worst fractal dimension M par rapport à worst fractal dimension B : {int(fractal_dimension_M_df["fractal_dimension_worst"].mean()/fractal_dimension_B_df["fractal_dimension_worst"].mean()*100)}%')
# Out:
# ratio worst rayon M par rapport à worst rayon B : 157 %
# ratio worst texture M par rapport à worst texture B : 124 %
# ratio worst périmètre M par rapport à worst périmètre B : 162 %
# ratio worst aire M par rapport à worst aire B : 254 %
# ratio worst smoothness M par rapport à worst smoothness B : 115 %
# ratio worst compactness M par rapport à worst compactness B : 205%
# ratio worst concavité M par rapport à worst concavité B : 271%
# ratio worst points concaves M par rapport à worst points concaves B : 244%
# ratio sworst ymétrie M par rapport à worst symétrie B : 119%
# ratio worst fractal dimension M par rapport à worst fractal dimension B : 115%

# %%
print(f'ratio marge erreur rayon par rapport à rayon moyen : {int(radius_df["radius_se"].mean()/radius_df["radius_mean"].mean()*100)} %')
print(f'ratio marge erreur texture par rapport à texture moyen : {int(texture_df["texture_se"].mean()/texture_df["texture_mean"].mean()*100)} %')
print(f'ratio marge erreur périmètre par rapport à périmètre moyen : {int(perimeter_df["perimeter_se"].mean()/perimeter_df["perimeter_mean"].mean()*100)} %')
print(f'ratio marge erreur aire par rapport à aire moyen : {int(area_df["area_se"].mean()/area_df["area_mean"].mean()*100)} %')
print(f'ratio marge erreur smoothness par rapport à smoothness moyen : {int(smoothness_df["smoothness_se"].mean()/smoothness_df["smoothness_mean"].mean()*100)} %')
print(f'ratio marge erreur compactness par rapport à compactness moyen : {int(compactness_df["compactness_se"].mean()/compactness_df["compactness_mean"].mean()*100)}%')
print(f'ratio marge erreur de concavité par rapport à de concavité moyen : {int(concavity_df["concavity_se"].mean()/concavity_df["concavity_mean"].mean()*100)}%')
print(f'ratio marge erreur points concaves par rapport à points concaves moyen : {int(concave_points_df["concave points_se"].mean()/concave_points_df["concave points_mean"].mean()*100)}%')
print(f'ratio marge erreur symétrie par rapport à symétrie moyen : {int(symmetry_df["symmetry_se"].mean()/symmetry_df["symmetry_mean"].mean()*100)}%')
print(f'ratio marge erreur fractal dimension par rapport à fractal dimension moyen : {int(fractal_dimension_df["fractal_dimension_se"].mean()/fractal_dimension_df["fractal_dimension_mean"].mean()*100)}%')
# Out:
# ratio marge erreur rayon par rapport à rayon moyen : 2 %
# ratio marge erreur texture par rapport à texture moyen : 6 %
# ratio marge erreur périmètre par rapport à périmètre moyen : 3 %
# ratio marge erreur aire par rapport à aire moyen : 6 %
# ratio marge erreur smoothness par rapport à smoothness moyen : 7 %
# ratio marge erreur compactness par rapport à compactness moyen : 24%
# ratio marge erreur de concavité par rapport à de concavité moyen : 35%
# ratio marge erreur points concaves par rapport à points concaves moyen : 24%
# ratio marge erreur symétrie par rapport à symétrie moyen : 11%
# ratio marge erreur fractal dimension par rapport à fractal dimension moyen : 6%

# %% [markdown]
# # Illustrer à l'aide de graphiques les variables les plus discriminantes

# %%
graphe=plt.figure(figsize=(12,8))
ax1=graphe.add_subplot(2,2,1)
ax2=graphe.add_subplot(2,2,2)
ax3=graphe.add_subplot(2,2,3)
ax4=graphe.add_subplot(2,2,4)

ax1.scatter(radius_B_df['radius_mean'], radius_B_df['radius_se'], color='blue', label='bénin')
ax1.scatter(radius_M_df['radius_mean'], radius_M_df['radius_se'], color='red', label='malin')
ax1.legend()
# ax1.set_xlabel('')
# ax1.set_ylabel('')
# ax1.set_xlim()
# ax1.set_ylim()

ax2.scatter(texture_B_df['texture_mean'], texture_B_df['texture_se'], color='blue', label='bénin')
ax2.scatter(texture_M_df['texture_mean'], texture_M_df['texture_se'], color='red', label='malin')
ax2.legend()
# ax2.set_xlabel('')
# ax2.set_ylabel('')
# ax2.set_xlim()
# ax2.set_ylim()

ax3.scatter(perimeter_B_df['perimeter_mean'], perimeter_B_df['perimeter_se'], color='blue', label='bénin')
ax3.scatter(perimeter_M_df['perimeter_mean'], perimeter_M_df['perimeter_se'], color='red', label='malin')
ax3.legend()
# ax3.set_xlabel('')
# ax3.set_ylabel('')
# ax3.set_xlim()
# ax3.set_ylim()

ax4.scatter(area_B_df['area_mean'], area_B_df['area_se'], color='blue', label='bénin')
ax4.scatter(area_M_df['area_mean'], area_M_df['area_se'], color='red', label='malin')
ax4.legend()
# ax4.set_xlabel('')
# ax4.set_ylabel('')
# ax4.set_xlim()
# ax4.set_ylim()

plt.show()

# %%
graphe=plt.figure(figsize=(12,8))
ax1=graphe.add_subplot(2,2,1)
ax2=graphe.add_subplot(2,2,2)
ax3=graphe.add_subplot(2,2,3)
ax4=graphe.add_subplot(2,2,4)

ax1.scatter(smoothness_B_df['smoothness_mean'], smoothness_B_df['smoothness_se'], color='blue', label='bénin')
ax1.scatter(smoothness_M_df['smoothness_mean'], smoothness_M_df['smoothness_se'], color='red', label='malin')
ax1.legend()
# ax1.set_xlabel('')
# ax1.set_ylabel('')
# ax1.set_xlim()
# ax1.set_ylim()

ax2.scatter(compactness_B_df['compactness_mean'], compactness_B_df['compactness_se'], color='blue', label='bénin')
ax2.scatter(compactness_M_df['compactness_mean'], compactness_M_df['compactness_se'], color='red', label='malin')
ax2.legend()
# ax2.set_xlabel('')
# ax2.set_ylabel('')
# ax2.set_xlim()
# ax2.set_ylim()

ax3.scatter(concavity_B_df['concavity_mean'], concavity_B_df['concavity_se'], color='blue', label='bénin')
ax3.scatter(concavity_M_df['concavity_mean'], concavity_M_df['concavity_se'], color='red', label='malin')
ax3.legend()
# ax3.set_xlabel('')
# ax3.set_ylabel('')
# ax3.set_xlim()
# ax3.set_ylim()

ax4.scatter(concave_points_B_df['concave points_mean'], concave_points_B_df['concave points_se'], color='blue', label='bénin')
ax4.scatter(concave_points_M_df['concave points_mean'], concave_points_M_df['concave points_se'], color='red', label='malin')
ax4.legend()
# ax4.set_xlabel('')
# ax4.set_ylabel('')
# ax4.set_xlim()
# ax4.set_ylim()

plt.show()

# %%
graphe=plt.figure(figsize=(12,8))
ax1=graphe.add_subplot(1,2,1)
ax2=graphe.add_subplot(1,2,2)

ax1.scatter(symmetry_B_df['symmetry_mean'], symmetry_B_df['symmetry_se'], color='blue', label='bénin')
ax1.scatter(symmetry_M_df['symmetry_mean'], symmetry_M_df['symmetry_se'], color='red', label='malin')
ax1.legend()
# ax1.set_xlabel('')
# ax1.set_ylabel('')
# ax1.set_xlim()
# ax1.set_ylim()

ax2.scatter(fractal_dimension_B_df['fractal_dimension_mean'], fractal_dimension_B_df['fractal_dimension_se'], color='blue', label='bénin')
ax2.scatter(fractal_dimension_M_df['fractal_dimension_mean'], fractal_dimension_M_df['fractal_dimension_se'], color='red', label='malin')
ax2.legend()
# ax2.set_xlabel('')
# ax2.set_ylabel('')
# ax2.set_xlim()
# ax2.set_ylim()

plt.show()
